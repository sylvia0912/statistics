# %% [markdown]
# ## Inferential Statistics
#
# With Inferential statistics u take data in form of samples and make generalizations about population.<br>
#
#
# It has two areas which are -
# ### 1. Estimating Parameter
# It means u take some statistics from sample data (e.g. sample mean) and use it to say something about population parameter (e.g. population mean).
# ### 2. Hypothesis Testing
# In hypothesis testing we use sample data to answer some research quetions. e.g. if a new cancer drug is effective?

# %% [markdown]
# ## Central Limit Theoram

# %% [markdown]
# ![Xnip2022-05-21_16-45-56.jpg](attachment:Xnip2022-05-21_16-45-56.jpg)
#
#
# **Note** -
# 1. A sampling distribution is a statistic that is arrived out through repeated sampling from a larger population.
# 2. Sample size equal to greater than 30 are often considered sufficient for CLT to hold.
# 3. As sample size will increase, the sampling distribution of mean starts closely resembling to a normal distribution as shown in figure below. As it closely resembles a normal distribution, the mean of this sampling distribution will be similar to population.

# %% [markdown]
# ![Xnip2022-05-21_16-46-07.jpg](attachment:Xnip2022-05-21_16-46-07.jpg)

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# 1. Hypothesis testing is the act of testing a hypothesis or a supposition in relation to a statistical parameter.
# 2. Analysts implement hypothesis testing in order to test if a hypothesis is plausible (new knowledge is repeatable & holds true for entire population) and that these results are not due to a random chance.

# %% [markdown]
# ## Purpose of Hypothesis testing

# %% [markdown]
# Purpose of hypothesis testing is to test whether null hypothesis can be rejected or approved.

# %% [markdown]
# ## Types of Hypothesis

# %% [markdown]
# ### 1. Alternative Hypothesis
# 1. Alternative Hypothesis (H1) or the research hypothesis states that there is a relationship between two variables (where one variable affects the other). The alternative hypothesis is the main driving force for hypothesis testing.
# 2. It implies that the two variables are related to each other and the relationship that exists between them is not due to chance or coincidence.
# 3. When the process of hypothesis testing is carried out, the alternative hypothesis is the main subject of the testing process. The analyst intends to test the alternative hypothesis and verifies its plausibility.
#
# **Note**<br>
# New knowledge discovered when u accept alternate hypothesis or reject null hypothesis.
#
#
# ### 2. Null Hypothesis
# 1. The Null Hypothesis (H0) aims to nullify the alternative hypothesis by implying that there exists no relation between two variables in statistics. It states that the effect of one variable on the other is solely due to chance and no empirical cause lies behind it
#
# **Note**<br>
# No new knowledge discovered. Original results hold true when u fail to reject null hypothesis.

# %% [markdown]
# ## Types of Hypothesis Tests

# %% [markdown]
# ## T-test
# 1. It is used to determine if there is significant difference b/w means(averages) of 2 groups which may be related in certain features.
# 2. T-test is used to answer a research question.For e.g. a drug company may want to test a new cancer drug to find out if it improves life expectancy of patients.
#
# ![Xnip2022-05-21_11-39-00.jpg](attachment:Xnip2022-05-21_11-39-00.jpg)

# %% [markdown]
# 3. CONTROL GROUP - refers to group of people not given new drug (normal old drug used)<br>
#    NEW DRUG GROUP/TREATMENT GROUP - refers to people tested on new drug.<br>
#    <br>
# 4. It could seem from above results that drug might work but it could be due to random chance. To test this researchers can use T-test to find out if results are repeatable for entire population.

# %% [markdown]
# ![Xnip2022-05-21_11-39-06.jpg](attachment:Xnip2022-05-21_11-39-06.jpg)

# %% [markdown]
# ## ANOVA

# %% [markdown]
# ![Xnip2022-05-21_11-39-15.jpg](attachment:Xnip2022-05-21_11-39-15.jpg)

# %% [markdown]
# ## Chi-square Goodness of Fit test

# %% [markdown]
# ![Xnip2022-05-21_13-03-45.jpg](attachment:Xnip2022-05-21_13-03-45.jpg)

# %% [markdown]
# ### Theoritical distribution
# These are distributions based on logic or mathematical formula's.
#
# ### Empirical distribution
# These are frequency distributions of observed values/actual values.<br>
# It is based on observations from an experiment.<br>
# In real world, mostly data is normally distributed i.e. follows normal distribution.
